# %% [markdown]
# ### **Importing**

# %%
import requests

# URL of the webpage you want to download
url = "https://www.oedc.com.ph/company-disclosure/"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Get the content of the response
    html_content = response.text
    
    # Save the content to a file
    with open("oedc_webpage.html", "w", encoding="utf-8") as file:
        file.write(html_content)
    
    print("The source code has been downloaded successfully.")
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# The source code has been downloaded successfully.

# %%
import requests
from bs4 import BeautifulSoup
import os

# Define the base URL to complete the relative links
base_url = "https://www.oedc.org.ph"  # Adjust according to the actual base URL if different
output_folder = "pdf downloads"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Load the HTML content
with open('oedc_webpage.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find all the links to PDF files
pdf_links = soup.find_all('a', href=True)

# Iterate through all the links and download the PDFs
for link in pdf_links:
    href = link['href']
    if href.endswith('.pdf'):  # Ensures only PDF files are downloaded
        pdf_url = base_url + href if href.startswith('/') else href
        pdf_name = os.path.join(output_folder, pdf_url.split('/')[-1])

        # Download the PDF
        response = requests.get(pdf_url)
        with open(pdf_name, 'wb') as pdf_file:
            pdf_file.write(response.content)
        
        print(f"Downloaded: {pdf_name}")

print("All PDFs have been downloaded.")
# Out:
# Downloaded: pdf downloads/Gen-Mix_for-Website-January-2024-2.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-February-2024.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-March-2024.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-April-2024.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-May-2024-1.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-June-2024.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-July-2024.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-August-2024.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-January-2023-1.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-February-2023-1.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-March-2023-1.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-April-2023-1.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-May-2023-2.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-June-2023.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-July-2023_2.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-August-2023.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-September-2023.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-October-2023.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-November-2023-1.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-December-2023.pdf
# Downloaded: pdf downloads/OEDC-January-2022-Generation-Rates.pdf
# Downloaded: pdf downloads/OEDC-February-2022-Generation-Rates.pdf
# Downloaded: pdf downloads/OEDC-March-2022-Generation-Rates.pdf
# Downloaded: pdf downloads/OEDC-April-2022-Generation-Rates.pdf
# Downloaded: pdf downloads/OEDC-May-2022-Generation-Rates.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-June-2022.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-July-2022.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-August-2022.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-September-2022.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-October-2022.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-November-2022.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-December-2022.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-January-2021.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-February-2021.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-March-2021.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-April-2021-v2.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-May-2021.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-July-2021.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-July-2021-1.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-August-2021.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-September-2021.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-October-2021.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-November-2021-V2.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-December-2021-V2.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-January-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-February-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-March-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-April-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-May-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-June-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-July-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-August-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-September-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-October-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-November-2020.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-December-2020.pdf
# Downloaded: pdf downloads/1.Gen-Mix_for-Website-January-2019.pdf
# Downloaded: pdf downloads/2.Gen-Mix_for-Website-February-2019.pdf
# Downloaded: pdf downloads/3.Gen-Mix_for-Website-March-2019.pdf
# Downloaded: pdf downloads/4.Gen-Mix_for-Website-April-2019.pdf
# Downloaded: pdf downloads/5.Gen-Mix_for-Website-May-2019.pdf
# Downloaded: pdf downloads/6.Gen-Mix_for-Website-June-2019.pdf
# Downloaded: pdf downloads/7.Gen-Mix_for-Website-July-2019.pdf
# Downloaded: pdf downloads/8.Gen-Mix_for-Website-August-2019.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-September-2019.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-October-2019.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-November-2019.pdf
# Downloaded: pdf downloads/Gen-Mix_for-Website-December-2019.pdf
# Downloaded: pdf downloads/1.Gen-Mix_for-Website-January-2018.pdf
# Downloaded: pdf downloads/2.Gen-Mix_for-Website-February-2018.pdf
# Downloaded: pdf downloads/3.Gen-Mix_for-Website-March-2018.pdf
# Downloaded: pdf downloads/4.Gen-Mix_for-Website-April-2018.pdf
# Downloaded: pdf downloads/5.Gen-Mix_for-Website-May-2018.pdf
# Downloaded: pdf downloads/6.Gen-Mix_for-Website-June-2018.pdf
# Downloaded: pdf downloads/7.Gen-Mix_for-Website-July-2018.pdf
# Downloaded: pdf downloads/8.Gen-Mix_for-Website-August-2018.pdf
# Downloaded: pdf downloads/9.Gen-Mix_for-Website-September-2018.pdf
# Downloaded: pdf downloads/10.Gen-Mix_for-Website-October-2018.pdf
# Downloaded: pdf downloads/11.Gen-Mix_for-Website-November-2018.pdf
# Downloaded: pdf downloads/12.Gen-Mix_for-Website-December-2018.pdf
# Downloaded: pdf downloads/1.Gen-Mix_for-Website-January-2017.pdf
# Downloaded: pdf downloads/2.Gen-Mix_for-Website-February-2017.pdf
# Downloaded: pdf downloads/3.Gen-Mix_for-Website-March-2017.pdf
# Downloaded: pdf downloads/Breakdown-of-Generation-Charge